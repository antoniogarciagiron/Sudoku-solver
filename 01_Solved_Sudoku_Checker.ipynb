# %%
import sys
sys.path.append("../")
from src.func import *

from keras.models import load_model
model = load_model('my_model_my_numbers.h5')

# %%
sudoku_pic = load_my_image("sudokusolved.png")
plt.imshow(sudoku_pic)

# %%
cut = sudoku_cut_frame("sudokusolved.png")
list_pics = sudoku_split_81(cut)
final_list, probability_numbers, number_pics = from_pic_to_numbers(list_pics)

# %%
plot_sudoku(final_list)
# Out:
# 5 3 4 | 6 7 8 | 9 1 2
# 6 7 2 | 1 9 5 | 3 4 8
# 1 9 8 | 3 4 2 | 5 6 7
# ---------------------
# 8 5 9 | 7 6 1 | 4 2 3
# 4 2 6 | 8 5 3 | 7 9 1
# 7 1 3 | 9 2 4 | 8 5 6
# ---------------------
# 9 6 1 | 5 3 7 | 2 8 4
# 2 8 7 | 4 1 9 | 6 3 5
# 3 4 5 | 2 8 6 | 1 7 9

# %%
rows = get_rows_array(final_list)
cols = get_cols_array(final_list)
quads = get_quads_array(final_list)

# %%
correct_or_not(rows, cols, quads)
# Out:
# The answer is good, well done! ;)
